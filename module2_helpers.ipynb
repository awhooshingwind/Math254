# %% [markdown]
# <a href="https://colab.research.google.com/github/awhooshingwind/Math254/blob/main/module2_helpers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np
from sympy import *
from scipy import integrate
import plotly.express as px
import math

init_printing()

# %%
# Lamina polar coordinates (inner and outer radii)

def solve_dbl(f, a, b):
  sol = integrate.dblquad(f, a, b, lambda x: 0, lambda x: np.pi/2)
  return sol

inner = 4
outer = 7

mf = lambda theta, r: np.cos(theta)
Mxf = lambda theta, r: r*np.sin(theta)*np.cos(theta)
Myf = lambda theta, r: r*np.cos(theta)**2

Mx = solve_dbl(Mxf, inner, outer)
My = solve_dbl(Myf, inner, outer)
m = solve_dbl(mf, inner, outer)

str_sol = f
print(Mx[0], My[0], m[0])
xbar, ybar = (My[0]/m[0], Mx[0]/m[0])
print (xbar, ybar)
# Out:
# 8.25 12.959069696057895 2.9999999999999996
# 4.319689898685966 2.7500000000000004

# %%
# Set parameters

# Def func
fxy = lambda x, y : 3*x**2 + 3*y**2
y = lambda x: 5*x**2
y2 = lambda x: x**2 + 5
# Def domain
xmin = -1.75
xmax = 1.75

ymin = -10
ymax = 10

n = 100
step = 0.25

x_vals = np.linspace(xmin, xmax, n)
y_vals = np.linspace(ymin, ymax, n)
X,Y = np.meshgrid(x_vals, y_vals)

# %%
# Plot Functions 2D
plt.plot(x_vals, y(x_vals))
plt.plot(x_vals, y2(x_vals))
#plt.vlines(9, 0, 9)

# %%
# calc integral
# func
# a, b limits wrt x
# gfun, hfun boundary curves wrt y
# def solve_double(f, a, b, gfun, hfun):
#   sol = integrate.dblquad(f, a, b, gfun, hfun)
#   return sol
# a = 0
# b = 9
# gfun = lambda x: 0
# hfun = lambda x: 6
# sol = solve_double(lambda x: x+2, a, b, gfun, hfun)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-165126b94f76> in <module>()
#      10 gfun = lambda x: 0
#      11 hfun = lambda x: 6
# ---> 12 sol = solve_double(lambda x:x+2, a, b, gfun, hfun)
#
# <ipython-input-35-165126b94f76> in solve_double(f, a, b, gfun, hfun)
#       4 # gfun, hfun boundary curves wrt y
#       5 def solve_double(f, a, b, gfun, hfun):
# ----> 6   sol = integrate.dblquad(f, a, b, gfun, hfun)
#       7   return sol
#       8 a = 0
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/quadpack.py in dblquad(func, a, b, gfun, hfun, args, epsabs, epsrel)
#     584
#     585     return nquad(func, [temp_ranges, [a, b]], args=args,
# --> 586             opts={"epsabs": epsabs, "epsrel": epsrel})
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/quadpack.py in nquad(func, ranges, args, opts, full_output)
# ...

# %%
# Function Plotter 3D
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})


# Make data.
X = np.arange(xmin, xmax, step)
Y = np.arange(ymin, ymax, step) 
X, Y = np.meshgrid(X, Y)
#R = np.sqrt(X**2 + Y**2)
Z = fxy(X,Y)

# Plot the surface.

# Customize the z axis.
zmin = 0
zmax = 1000
ax.set_zlim(zmin, zmax)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
# ax.zaxis.set_major_formatter('{x:.02f}')

#surf = make_surf(X, Y, Z)
surf = ax.plot_surface(X, Y, Z, cmap=cm.Spectral,linewidth=0, antialiased=False)
# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
